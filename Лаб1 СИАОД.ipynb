# %% [markdown]
# # Лабораторная работа №1
# ## Выполнил студент группы БВТ2101 Козей Михаил Александрович

# %% [markdown]
# ### Оглавление
# 1. [Задание 1](#Задание-№1)
# 2. [Задание 2](#Задание-№2)
# 3. [Задание 3](#Задание-№3)
# 4. [Вывод](#Вывод)

# %% [markdown]
# ### Задание №1
# <i> Вызвать функцию print() и передать туда строку Hello, World! </i>

# %%
print('Hello, world!')
# Out:
# Hello, world!

# %% [markdown]
# ### Задание №2
# Написать генератор случайных матриц(многомерных), который принимает
# опциональные параметры <b>m</b>, <b>n</b>, <b>min_limit</b>, <b>max_limit</b>, где <b>m</b> и <b>n</b> указывают размер
# матрицы, а <b>min_lim</b> и <b>max_lim</b> - минимальное и максимальное значение для
# генерируемого числа.

# %%
import random
import time

# %%
user_m = int(input())
user_n = int(input())
user_min_limit = int(input())
user_max_limit = int(input())
Matrix = [ [ random.randint(user_min_limit, user_max_limit) for j in range(user_n)] for i in range(user_m) ]
for i in range(user_m):
    print(Matrix[i])
# Out:
# [33, 38, 94, 42, 87, 71, 20, 61, 39, 95, 98, 94, 24, 80, 4, 90, 41, 2, 43, 73, 52, 45, 67, 42, 82, 75, 41, 20, 13, 45, 58, 78, 35, 27, 33, 77, 70, 68, 17, 96, 81, 86, 60, 44, 35, 57, 40, 100, 7, 90, 80, 59, 72, 35, 90, 69, 41, 59, 21, 20, 31, 72, 84, 84, 86, 74, 87, 62, 89, 74, 83, 15, 60, 68, 81, 95, 52, 100, 74, 82, 27, 4, 63, 6, 82, 26, 54, 27, 21, 85, 72, 54, 41, 71, 17, 95, 55, 85, 63, 85]
# [51, 63, 18, 29, 85, 99, 85, 26, 2, 32, 69, 4, 86, 80, 52, 36, 94, 27, 86, 59, 40, 55, 90, 98, 70, 31, 24, 11, 54, 70, 81, 62, 99, 72, 34, 89, 2, 33, 19, 43, 35, 48, 2, 41, 33, 49, 23, 4, 21, 26, 64, 44, 80, 97, 57, 67, 49, 26, 12, 87, 98, 24, 41, 37, 3, 78, 93, 19, 95, 79, 38, 51, 75, 39, 79, 6, 55, 97, 7, 75, 75, 13, 96, 26, 28, 92, 69, 46, 19, 93, 38, 37, 23, 33, 51, 80, 68, 72, 32, 11]
# ...

# %% [markdown]
# ### Задание №3
# Реализовать методы сортировки строк числовой матрицы в соответствии с
# заданием. Оценить время работы каждого алгоритма сортировки и сравнить его со
# временем стандартной функции сортировки. Испытания проводить на сгенерированных
# матрицах.

# %%
import copy

# %%
# Сортировка выбором.
# Берётся срез массива, в котором минимальный элемент переносят в самый левый угол,
# после чего срез уменьшается и цикл повторяется.

Matrix = [ [ random.randint(user_min_limit, user_max_limit) for j in range(user_n)] for i in range(user_m) ]
start_time = time.time()
def selection_sort(arr): 
    for i in range(len(arr)): 
        min_idx = i 
        for j in range(i+1, len(arr)): 
            if arr[min_idx] > arr[j]: 
                min_idx = j 
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
    return arr
for row in range(len(Matrix)):
     selection_sort(Matrix[row])
# sort_arr = selection_sort(Matrix)
time1 = "--- {0} ms ---".format(round((time.time() - start_time)*1000))

# %%
# Сортировка вставкой.
start_time = time.time()
def insertion_sort(arr): 
    for i in range(1, len(arr)): 
        key = arr[i] 
        j = i-1
        while j >=0 and key < arr[j] : 
                arr[j+1] = arr[j] 
                j -= 1
        arr[j+1] = key 
    return arr
for row in range(len(Matrix)):
     insertion_sort(Matrix[row])
# sort_arr = insertion_sort(Matrix)
time2 = "--- {0} ms ---".format(round((time.time() - start_time)*1000))

# %%
# Сортировка обменом. || Сортировка пузырьком.
Matrix = [ [ random.randint(user_min_limit, user_max_limit) for j in range(user_n)] for i in range(user_m) ]
start_time = time.time()
def bubble_sort(arr): 
    n = len(arr) 
    for i in range(n): 
        for j in range(0, n-i-1): 
            if arr[j] > arr[j+1] : 
                arr[j], arr[j+1] = arr[j+1], arr[j] 
    return arr
for row in range(len(Matrix)):
     bubble_sort(Matrix[row]) 
# sort_arr = bubble_sort(Matrix) 
time3 = "--- {0} ms ---".format(round((time.time() - start_time)*1000))

# %%
# Сортировка Шелла.
Matrix = [ [ random.randint(user_min_limit, user_max_limit) for j in range(user_n)] for i in range(user_m) ]
start_time = time.time()
def shell_sort(arr): 
    n = len(arr) 
    gap = n//2
    while gap > 0: 
        for i in range(gap,n): 
            temp = arr[i] 
            j = i 
            while  j >= gap and arr[j-gap] >temp: 
                arr[j] = arr[j-gap] 
                j -= gap 
            arr[j] = temp 
        gap //= 2
    return arr
for row in range(len(Matrix)):
     insertion_sort(Matrix[row]) 
# sort_arr = shell_sort(Matrix)
time4 = "--- {0} ms ---".format(round((time.time() - start_time)*1000))

# %%
# Быстрая сортировка.
Matrix = [ [ random.randint(user_min_limit, user_max_limit) for j in range(user_n)] for i in range(user_m) ]
start_time = time.time()
def quick_sort(mas):
    quick_sort_helper(mas, 0, len(mas) - 1)
    return mas


def quick_sort_helper(mas, low, high):
    if low < high:
        split_point = partition(mas, low, high)
        quick_sort_helper(mas, low, split_point - 1)
        quick_sort_helper(mas, split_point + 1, high)


def partition(mas, low, high):
    pivot_value = mas[low]
    left_mark = low + 1
    right_mark = high
    done = False

    while not done:
        while left_mark <= right_mark and mas[left_mark] <= pivot_value:
            left_mark += 1
        while right_mark >= left_mark and mas[right_mark] >= pivot_value:
            right_mark -= 1

        if right_mark < left_mark:
            done = True
        else:
            mas[left_mark], mas[right_mark] = mas[right_mark], mas[left_mark]

    mas[low], mas[right_mark] = mas[right_mark], mas[low]
    return right_mark
for row in range(len(Matrix)):
     quick_sort(Matrix[row])
# sort_arr = quick_sort(Matrix)   
time5 = "--- {0} ms ---".format(round((time.time() - start_time)*1000))

# %%
# Турнирная сортировка.
Matrix = [ [ random.randint(user_min_limit, user_max_limit) for j in range(user_n)] for i in range(user_m) ]
start_time = time.time()
def tournament_sort(arr): 
    if len(arr) > 1: 
        mid = len(arr) // 2
        left = arr[:mid]
        right = arr[mid:] 
        tournament_sort(left) 
        tournament_sort(right) 
        i = 0
        j = 0
        k = 0
        while i < len(left) and j < len(right): 
            if left[i] < right[j]: 
                arr[k]=left[i] 
                i+=1
            else: 
                arr[k]=right[j] 
                j+=1
            k+=1
        while i < len(left): 
            arr[k]=left[i] 
            i+=1
            k+=1
        while j < len(right): 
            arr[k]=right[j] 
            j+=1
            k+=1
    return arr
for row in range(len(Matrix)):
     tournament_sort(Matrix[row]) 
# sort_arr = tournament_sort(Matrix)   
time6 = "--- {0} ms ---".format(round((time.time() - start_time)*1000))

# %%
Matrix = [ [ random.randint(user_min_limit, user_max_limit) for j in range(user_n)] for i in range(user_m) ]
start_time = time.time()
def std_sort(arr):
    arr.sort()
time7 = "--- {0} ms ---".format(round((time.time() - start_time)*1000))

# %%
import time
import random
import matplotlib.pyplot as plt
N = [100,200,300,400,500,600,700,800,900,1000,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000]
T_selection = []
T_insertion = []
T_bubble = []
T_shell = []
T_quick = []
T_tournament = []
T_standard = []
for n in N:
    arr = [random.randint(0, n) for _ in range(n)]
    # Selection Sort
    start = time.time()
    selection_sort(arr)
    end = time.time()
    T_selection.append((end-start)*1000)
    # Insertion Sort
    start = time.time()
    insertion_sort(arr)
    end = time.time()
    T_insertion.append((end-start)*1000)
    # Bubble Sort
    start = time.time()
    bubble_sort(arr)
    end = time.time()
    T_bubble.append((end-start)*1000)
    # Shell Sort
    start = time.time()
    shell_sort(arr)
    end = time.time()
    T_shell.append((end-start)*1000)
    # Quick Sort
    start = time.time()
    quick_sort(arr)
    end = time.time()
    T_quick.append((end-start)*1000)
    # Tournament Sort
    start = time.time()
    tournament_sort(arr)
    end = time.time()
    T_tournament.append((end-start)*1000)
    # Standard Sort
    start = time.time()
    std_sort(arr)
    end = time.time()
    T_standard.append((end-start)*1000)
# Plotting
plt.plot(N, T_selection, label="Selection Sort")
plt.plot(N, T_bubble, label="Bubble Sort")
plt.plot(N, T_quick, label="Quick Sort")
plt.xlabel('Size of matrix')
plt.ylabel('Time (in ms)')
plt.title('Sorting Algorithm Comparison')
plt.legend()
plt.show()
plt.plot(N, T_insertion, label="Insertion Sort")
plt.plot(N, T_shell, label="Shell Sort")
plt.plot(N, T_tournament, label="Tournament Sort")
plt.plot(N, T_standard, label="Standard Sort")
plt.xlabel('Size of matrix')
plt.ylabel('Time (in ms)')
plt.title('Sorting Algorithm Comparison')
plt.legend()
plt.show()

# %% [markdown]
# ### Вывод

# %%
print("Время сортировки матриц", user_m, "*", user_n)
print("Время сортировки выбором", time1)
print("Время сортировки вставкой", time2)
print("Время сортировки пузырьком", time3)
print("Время сортировки Шелла", time4)
print("Время быстрой сортировки", time5)
print("Время турнирной сортировки", time6)
print("Время стандартной сортировки", time7)
# Out:
# Время сортировки матриц 100 * 100
# Время сортировки выбором --- 69 ms ---
# Время сортировки вставкой --- 4 ms ---
# Время сортировки пузырьком --- 125 ms ---
# Время сортировки Шелла --- 58 ms ---
# Время быстрой сортировки --- 22 ms ---
# Время турнирной сортировки --- 57 ms ---
# Время стандартной сортировки --- 1 ms ---
